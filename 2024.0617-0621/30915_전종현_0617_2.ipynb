# %% [markdown]
# ## 30915_전종현_0617_2

# %% [markdown]
# ## 산점도 그리기

# %%
# 라이브러리 불러오기 및 별명 지정하기
import matplotlib.pyplot as plt
# 한글 폰트 불러오기
plt.rc("font",family='Malgun Gothic')
#랜덤 라이브러리 불러오기
import random
# 데이터 만들기
height,weight= [],[]
for i in range(100):
    height.append(random.randint(100,200))
    weight.append(random.randint(20,100))
    
# 제목 : 키와 몸무게의 상관관계
plt.title("키와 몸무게의 상관관계")
# 산점도 그래프 그리기
plt.scatter(height,weight,c=height,cmap='RdPu')
# 축 제목 
plt.colorbar(label='키')
plt.xlabel("키")
plt.ylabel("몸무게")

plt.show()

# %%
# 라이브러리 불러오기 및 별명 지정하기
import matplotlib.pyplot as plt
# 한글 폰트 불러오기
plt.rc("font",family='Malgun Gothic')
#랜덤 라이브러리 불러오기
import random
# 데이터 만들기
height,weight,score= [],[],[]
for i in range(100):
    height.append(random.randint(100,200))
    weight.append(random.randint(20,100))
    score.append(random.randint(1,1000))
    
# 제목 : 키와 몸무게의 상관관계
plt.title("키와 몸무게의 상관관계")
# 산점도 그래프 그리기
plt.scatter(height,weight,score,c=score,cmap='rainbow',alpha=0.7)
# 축 제목 
plt.colorbar(label='체육 실기 점수')
plt.xlabel("키")
plt.ylabel("몸무게")

plt.show()

# %%
kor = [80,20,50,20,10,50,60,30,60]
# 상자수염 차트 boxplot
plt.boxplot(kor)
plt.show()

# %% [markdown]
# ## 그래프 겹쳐 그리기
# ### 꺾은선 그래프 겹쳐 그리기

# %%
import matplotlib.pyplot as plt
singer=['A','B','C','D','E']
week1 = [42,58,19,92,84]
week2 = [53,52,48,98,73]

# 꺾은 선형 겹쳐그리기
plt.plot(singer,week1)
plt.plot(singer,week2)

plt.show()

# %%
import matplotlib.pyplot as plt
singer=['A','B','C','D','E']
week1 = [42,58,19,92,84]
week2 = [53,52,48,98,73]

plt.title("오디션 프로그램 득표 현황")
# 꺾은 선형 겹쳐그리기
plt.plot(singer,week1,color='hotpink',label='첫째주')
plt.plot(singer,week2,color='royalblue',label='둘째주')
plt.legend()
plt.show()
